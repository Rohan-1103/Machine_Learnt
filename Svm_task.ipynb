# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-1103/Machine_Learnt/blob/main/Svm_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ### Information:
#   - No missing values in any column
#   - Total records: 10108
#   - Total features: 18

# %%
import pandas as pd

credit_dataset = pd.read_csv('/content/credit_card.csv')
credit_dataset = credit_dataset.drop(columns=['Client_Num', 'Week_Start_Date', 'Week_Num', 'Qtr', 'current_year', 'Interest_Earned'])
credit_dataset.head()
# Out:
#   Card_Category  Annual_Fees  Activation_30_Days  Customer_Acq_Cost  \
# 0          Blue          200                   0                 87
# 1          Blue          445                   1                108
# 2          Blue          140                   0                106
# 3          Blue          250                   1                150
# 4          Blue          320                   1                106
#
#    Credit_Limit  Total_Revolving_Bal  Total_Trans_Amt  Total_Trans_Vol  \
# 0        3544.0                 1661            15149              111
# 1        3421.0                 2517              992               21
# 2        8258.0                 1771             1447               23
# 3        1438.3                    0             3940               82
# 4        3128.0                  749             4369               59
#
#    Avg_Utilization_Ratio Use Chip       Exp Type  Delinquent_Acc
# ...

# %%
y = credit_dataset['Delinquent_Acc']
x = credit_dataset.drop(columns=['Delinquent_Acc'])

# %%
y.value_counts()
# Out:
# Delinquent_Acc
# 0    9494
# 1     614
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, stratify=y, random_state=3)

# %%
categorical_cols = x_train.select_dtypes(include='object').columns
numerical_cols = x_train.select_dtypes(exclude='object').columns

print("Categorical columns:", list(categorical_cols))
print("Numerical columns:", list(numerical_cols))
# Out:
# Categorical columns: ['Card_Category', 'Use Chip', 'Exp Type']
# Numerical columns: ['Annual_Fees', 'Activation_30_Days', 'Customer_Acq_Cost', 'Credit_Limit', 'Total_Revolving_Bal', 'Total_Trans_Amt', 'Total_Trans_Vol', 'Avg_Utilization_Ratio']

# %%
from sklearn.preprocessing import LabelEncoder

# Apply LabelEncoder to categorical columns
for col in categorical_cols:
    le = LabelEncoder()
    x_train[col] = le.fit_transform(x_train[col])
    x_test[col] = le.transform(x_test[col])

# %%
from sklearn.preprocessing import StandardScaler

# Apply StandardScaler to numerical columns
scaler = StandardScaler()
x_train[numerical_cols] = scaler.fit_transform(x_train[numerical_cols])
x_test[numerical_cols] = scaler.transform(x_test[numerical_cols])

# %%
from sklearn.svm import SVC

classifier = SVC(kernel='linear', random_state=3) # Added random_state for reproducibility
classifier.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', random_state=3)

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
# Out:
# Accuracy: 0.9392
# Precision: 0.0000
# Recall: 0.0000
# F1-Score: 0.0000
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
