# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-1103/Machine_Learnt/blob/main/FuelConsumption_MLR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/petrol_consumption.csv')
df
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
# input and target variable
x = df.iloc[:, :4]
y = df.iloc[:, -1]
x, y

# train test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=2)

# %%
# applying multiple linear regression
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# calculating r2-score
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, root_mean_squared_error
r2 = r2_score(y_test, y_test)
print("R2 score RAW: ", r2)

mse = mean_squared_error(y_test, y_pred)
print("MSE RAW: ", mse)

mae = mean_absolute_error(y_test, y_pred)
print("MAE RAW: ", mae)

rsme = root_mean_squared_error(y_test, y_pred)
print("RSME: ", rsme)
# Out:
# R2 score RAW:  1.0
# MSE RAW:  4161.757977472344
# MAE RAW:  56.618686587009634
# RSME:  64.51168868873565

# %%
import pickle

# Save the model to a pickle file with .pkl extension
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)

print("Model saved as model.pkl")
# Out:
# Model saved as model.pkl
